# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %%
train = pd.read_csv('data.csv')

# %%
train
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %% [markdown]
# # EDA And Feature Engineering

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
train['date'].unique()
# Out:
# array(['2014-05-02 00:00:00', '2014-05-03 00:00:00',
#        '2014-05-04 00:00:00', '2014-05-05 00:00:00',
#        '2014-05-06 00:00:00', '2014-05-07 00:00:00',
#        '2014-05-08 00:00:00', '2014-05-09 00:00:00',
#        '2014-05-10 00:00:00', '2014-05-11 00:00:00',
#        '2014-05-12 00:00:00', '2014-05-13 00:00:00',
#        '2014-05-14 00:00:00', '2014-05-15 00:00:00',
#        '2014-05-16 00:00:00', '2014-05-17 00:00:00',
#        '2014-05-18 00:00:00', '2014-05-19 00:00:00',
#        '2014-05-20 00:00:00', '2014-05-21 00:00:00',
#        '2014-05-22 00:00:00', '2014-05-23 00:00:00',
#        '2014-05-24 00:00:00', '2014-05-25 00:00:00',
#        '2014-05-26 00:00:00', '2014-05-27 00:00:00',
#        '2014-05-28 00:00:00', '2014-05-29 00:00:00',
#        '2014-05-30 00:00:00', '2014-05-31 00:00:00',
#        '2014-06-01 00:00:00', '2014-06-02 00:00:00',
#        '2014-06-03 00:00:00', '2014-06-04 00:00:00',
#        '2014-06-05 00:00:00', '2014-06-06 00:00:00',
# ...

# %% [markdown]
# NOTE: Since all belong to the same year, just taking the month and date of reading will be fine

# %%
train["date"] = train["date"].astype('string')

# %%
train["month"] = train["date"].apply(lambda x: (x.split()[0]).split("-")[1])

# %%
train["date"] = train["date"].apply(lambda x: (x.split()[0]).split("-")[2])

# %%
train
# Out:
#      date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      02  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1      02  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2      02  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3      02  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4      02  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...   ...           ...       ...        ...          ...       ...     ...
# 4595   09  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596   09  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597   09  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598   10  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599   10  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %% [markdown]
# NOTE: yr_renovated is same as yr_built in case of 0

# %%
train.loc[train['yr_renovated'] == 0, 'yr_renovated'] = train['yr_built']

# %%
train
# Out:
#      date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      02  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1      02  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2      02  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3      02  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4      02  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...   ...           ...       ...        ...          ...       ...     ...
# 4595   09  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596   09  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597   09  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598   10  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599   10  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %% [markdown]
# Removing the number of the street

# %%
train["street"] = train["street"].apply(lambda x: " ".join(x.split()[1:]))

# %%
train
# Out:
#      date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      02  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1      02  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2      02  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3      02  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4      02  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...   ...           ...       ...        ...          ...       ...     ...
# 4595   09  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596   09  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597   09  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598   10  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599   10  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %%
train['statezip'].astype(str).apply(lambda x :x.split()[0]).unique()
# Out:
# array(['WA'], dtype=object)

# %%
train['statezip'] = train['statezip'].astype(str).apply(lambda x:x.split()[1])

# %%
train
# Out:
#      date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      02  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1      02  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2      02  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3      02  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4      02  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...   ...           ...       ...        ...          ...       ...     ...
# 4595   09  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596   09  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597   09  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598   10  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599   10  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %%
train['country'].unique()
# Out:
# array(['USA'], dtype=object)

# %%
train.drop(columns = ['country'], inplace=True)

# %%
train
# Out:
#      date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      02  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1      02  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2      02  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3      02  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4      02  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...   ...           ...       ...        ...          ...       ...     ...
# 4595   09  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596   09  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597   09  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598   10  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599   10  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %%
train['street'].nunique()
# Out:
# 2608

# %%
#Count Encoding street, since the number of houses on a street can you provide a lot of information
train['street'] = train['street'].map(train['street'].value_counts().to_dict())

# %%
train['city'].nunique()
# Out:
# 44

# %%
train['city'] = train['city'].map(train['city'].value_counts().to_dict())

# %%
train.head()
# Out:
#    date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0   2.0   313000.0       3.0       1.50       1340.0    7912.0     1.5
# 1   2.0  2384000.0       5.0       2.50       3650.0    9050.0     2.0
# 2   2.0   342000.0       3.0       2.00       1930.0   11947.0     1.0
# 3   2.0   420000.0       3.0       2.25       2000.0    8030.0     1.0
# 4   2.0   550000.0       4.0       2.50       1940.0   10500.0     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0        3.0      1340.0            0.0    1955.0
# 1         0.0   4.0        5.0      3370.0          280.0    1921.0
# 2         0.0   0.0        4.0      1930.0            0.0    1966.0
# 3         0.0   0.0        4.0      1000.0         1000.0    1963.0
# 4         0.0   0.0        4.0      1140.0          800.0    1976.0
#
#    yr_renovated  street  city  statezip  month
# 0        2005.0     7.0   123   98133.0    5.0
# ...

# %%
train = train.astype(float)

# %%
train.isna().sum().sum()
# Out:
# 0

# %%
train.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'month'],
#       dtype='object')

# %% [markdown]
# I know street is important, but thinking of more strategies will require time, which I don't have right now. So just gonna drop it for now

# %%
X = train[['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'sqft_above',
       'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
       'statezip', 'month']]
y = train['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=7286)

# %% [markdown]
# # Models

# %%
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.linear_model import (Ridge, ElasticNet, SGDRegressor, BayesianRidge,
                                LinearRegression, Lasso, LassoLars, PassiveAggressiveRegressor,
                                HuberRegressor, TheilSenRegressor, RANSACRegressor)
from sklearn.ensemble import (RandomForestRegressor, GradientBoostingRegressor,
                            AdaBoostRegressor, BaggingRegressor, ExtraTreesRegressor)
from sklearn.tree import DecisionTreeRegressor, ExtraTreeRegressor
from sklearn.neighbors import KNeighborsRegressor, RadiusNeighborsRegressor
from sklearn.neural_network import MLPRegressor

# %%
models_list = {
    'SVR': SVR(),
    'XGBRegressor': XGBRegressor(),
    'SGDRegressor': SGDRegressor(),
    'BayesianRidge': BayesianRidge(),
    'LinearRegression': LinearRegression(),
    'RandomForestRegressor': RandomForestRegressor(),
    'AdaBoostRegressor': AdaBoostRegressor(),
    'BaggingRegressor': BaggingRegressor(),
    'ExtraTreesRegressor': ExtraTreesRegressor(),
    'KNeighborsRegressor': KNeighborsRegressor(),
    'MLPRegressor': MLPRegressor()
}

# %%
model_rmse = []
model_names = []
model_r2 = []
for name, model in models_list.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    model_rmse.append(rmse)
    model_names.append(name)
    model_r2.append(r2)

# %%
results = {
    'Name': model_names,
    'RMSE': model_rmse,
    'R2': model_r2
}

# %%
resultsdf = pd.DataFrame(results).sort_values(by='RMSE', ascending=False)

# %%
resultsdf
# Out:
#                      Name          RMSE            R2
# 2            SGDRegressor  5.287794e+18 -3.164531e+25
# 6       AdaBoostRegressor  9.652253e+05 -5.442993e-02
# 0                     SVR  9.485971e+05 -1.841294e-02
# 7        BaggingRegressor  9.397969e+05  3.952916e-04
# 1            XGBRegressor  9.319568e+05  1.700369e-02
# 5   RandomForestRegressor  9.202461e+05  4.155268e-02
# 9     KNeighborsRegressor  9.172894e+05  4.770153e-02
# 10           MLPRegressor  9.122743e+05  5.808624e-02
# 3           BayesianRidge  9.108898e+05  6.094301e-02
# 4        LinearRegression  9.059112e+05  7.118006e-02
# 8     ExtraTreesRegressor  9.056301e+05  7.175632e-02

# %% [markdown]
# Best model is bagging model of ExtraTreesRegressor

# %% [markdown]
# ## ExtraTreesRegressor

# %%
extra_trees = ExtraTreesRegressor(random_state=10)

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
}

grid_search = GridSearchCV(estimator=extra_trees, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(random_state=10), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Use the best model for predictions
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print("Root Mean Squared Error (RMSE):", rmse)
print("R2 Score:", r2)
# Out:
# Best Hyperparameters: {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Root Mean Squared Error (RMSE): 904594.7094090905
# R2 Score: 0.07387760263824106

# %% [markdown]
# Still not a good RMSE

# %% [markdown]
# Maybe, too many features, need to do PCA

# %% [markdown]
# # PCA and dimensionality reduction

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=None)
pca.fit(X)
# Out:
# PCA()

# %%
cumulative_variance_ratio = np.cumsum(pca.explained_variance_ratio_)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance_ratio) + 1), cumulative_variance_ratio)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance Ratio')
plt.title('Explained Variance Ratio vs. Number of Components')
plt.grid(True)
plt.show()

# %% [markdown]
# OOF

# %%
pca = PCA(n_components=1)
X_pca = pca.fit_transform(X)

# %%
X_pca
# Out:
# array([[-6945.48063181],
#        [-5789.12960438],
#        [-2904.42993445],
#        ...,
#        [-7825.91635992],
#        [-8229.51762227],
#        [-6753.54218048]])

# %%
model_rmsepca = []
model_namespca = []
model_r2pca = []
for name, model in models_list.items():
    model.fit(X_trainpca, y_trainpca)
    y_pred = model.predict(X_testpca)

    rmse = np.sqrt(mean_squared_error(y_testpca, y_pred))
    r2 = r2_score(y_testpca, y_pred)

    model_rmsepca.append(rmse)
    model_namespca.append(name)
    model_r2pca.append(r2)

# %%
resultspca = {
    'Name': model_namespca,
    'RMSE': model_rmsepca,
    'R2': model_r2pca
}

# %%
resultsdfpca = pd.DataFrame(resultspca).sort_values(by='RMSE', ascending=False)

# %%
resultsdfpca
# Out:
#                      Name          RMSE            R2
# 2            SGDRegressor  7.524554e+15 -6.407990e+19
# 10           MLPRegressor  9.956240e+05 -1.218918e-01
# 6       AdaBoostRegressor  9.765686e+05 -7.935884e-02
# 8     ExtraTreesRegressor  9.757010e+05 -7.744166e-02
# 7        BaggingRegressor  9.727608e+05 -7.095791e-02
# 5   RandomForestRegressor  9.694204e+05 -6.361531e-02
# 9     KNeighborsRegressor  9.545854e+05 -3.131156e-02
# 0                     SVR  9.485948e+05 -1.840793e-02
# 1            XGBRegressor  9.466687e+05 -1.427653e-02
# 3           BayesianRidge  9.407321e+05 -1.595223e-03
# 4        LinearRegression  9.407313e+05 -1.593386e-03
